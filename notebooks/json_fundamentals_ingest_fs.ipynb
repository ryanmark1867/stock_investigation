# %% [markdown]
# # JSON Fundamentals ingest
#
# - bring JSON files into dataframes experiment

# %%
import pandas as pd
import numpy as np
import pickle
import os
import requests
import json
from io import StringIO
import yaml
from datetime import date
import requests
from sklearn.metrics import classification_report
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
#import pandas_datareader as pdr
from pandas_datareader.data import DataReader
# import yahoo_fin.stock_info as si

# For time stamps
from datetime import datetime

# for LSTM
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input
from keras.models import Model
# from tensorflow.keras.layers import Input, Dropout, Dense, BatchNormalization, Activation, concatenate, GRU, Embedding, Flatten, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
# access datasets from quandl.com - need to pip install Quandl to use
import quandl
config_file = 'json_ingest_config.yml'
# Out:
# Using TensorFlow backend.

# %%
# load config file
current_path = os.getcwd()
print("current directory is: "+current_path)

path_to_yaml = os.path.join(current_path, config_file)
print("path_to_yaml "+path_to_yaml)
try:
    with open (path_to_yaml, 'r') as c_file:
        config = yaml.safe_load(c_file)
except Exception as e:
    print('Error reading the config file')
# Out:
# current directory is: C:\personal\karma_stocks_2021\stock_investigation\notebooks
# path_to_yaml C:\personal\karma_stocks_2021\stock_investigation\notebooks\json_ingest_config.yml

# %%
# load config parms
parms = {}
eod_token = config['general']['eod_token']
eod_historical_token = config['general']['eod_historical_token']
fundamentals_directory = config['files']['fundamentals_directory']

from_date = config['general']['master_start']
to_date = config['general']['master_end']
parms['master_date_mode'] = config['general']['master_date_mode']
parms['master_start'] = config['general']['master_start']
parms['master_end'] = config['general']['master_end']

# %% [markdown]
# # Helper functions

# %%
# DataReader: https://riptutorial.com/pandas/topic/1912/pandas-datareader
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
# 
# Set up End and Start times for data grab
# check to see if start and end dates are hard-coded with master dates
def set_start_end():
    if parms['master_date_mode']: # start and end hardcoded by parameters
        start = parms['master_start']
        end = parms['master_end']
    else: # end is current date; start is current date minus years_window
        end = datetime.now()
        start = datetime(end.year - parms['years_window'], end.month, end.day)
    # output a test dataset
    tester = DataReader('IBM', 'stooq', start, end)
    print(tester.shape)
    return(start,end)

# %%
def get_path():
    rawpath = os.getcwd()
    # data is in a directory that is a sibling to the directory containing the notebook
    path = os.path.abspath(os.path.join(rawpath, '..', fundamentals_directory))
    return(path)

# %% [markdown]
# # Bring sample JSON file into Pandas dataframe

# %%
json_filename = "ABX_2021-10-18.json"
json_file = os.path.join(get_path(),json_filename)
df = pd.read_json(json_file)
df.head()
# Out:
#                                General Highlights  Valuation  SharesStats  \
# Code                               ABX        NaN        NaN          NaN
# Type                      Common Stock        NaN        NaN          NaN
# Name          Barrick Gold Corporation        NaN        NaN          NaN
# Exchange                            TO        NaN        NaN          NaN
# CurrencyCode                       CAD        NaN        NaN          NaN
#
#               Technicals SplitsDividends  Holders  InsiderTransactions  \
# Code                 NaN             NaN      NaN                  NaN
# Type                 NaN             NaN      NaN                  NaN
# Name                 NaN             NaN      NaN                  NaN
# Exchange             NaN             NaN      NaN                  NaN
# CurrencyCode         NaN             NaN      NaN                  NaN
#
#              ESGScores outstandingShares Earnings Financials
# Code               NaN               NaN      NaN        NaN
# Type               NaN               NaN      NaN        NaN
# Name               NaN               NaN      NaN        NaN
# Exchange           NaN               NaN      NaN        NaN
# CurrencyCode       NaN               NaN      NaN        NaN

# %%
df.head(30)
# Out:
#                                                                  General  \
# Code                                                                 ABX
# Type                                                        Common Stock
# Name                                            Barrick Gold Corporation
# Exchange                                                              TO
# CurrencyCode                                                         CAD
# CurrencyName                                             Canadian Dollar
# CurrencySymbol                                                        C$
# CountryName                                                       Canada
# CountryISO                                                            CA
# ISIN                                                        CA0679011084
# CIK                                                                 None
# EmployerIdNumber                                                    None
# FiscalYearEnd                                                   December
# IPODate                                                             None
# InternationalDomestic                                               None
# Sector                                                   Basic Materials
# Industry                                                            Gold
# GicSector                                                           None
# GicGroup                                                            None
# GicIndustry                                                         None
# GicSubIndustry                                                      None
# Description            Barrick Gold Corporation engages in the explor...
# Address                TD Canada Trust Tower, Toronto, ON, Canada, M5...
# AddressData            {'Street': 'TD Canada Trust Tower', 'City': 'T...
# Listings                                                              {}
# Officers               {'0': {'Name': 'Mr. John Lawson Thornton', 'Ti...
# Phone                                                       416 861 9911
# WebURL                                            http://www.barrick.com
# LogoURL                                            /img/logos/TO/ABX.png
# FullTimeEmployees                                                      0
#
#                       Highlights  Valuation  SharesStats  Technicals  \
# Code                         NaN        NaN          NaN         NaN
# Type                         NaN        NaN          NaN         NaN
# Name                         NaN        NaN          NaN         NaN
# Exchange                     NaN        NaN          NaN         NaN
# CurrencyCode                 NaN        NaN          NaN         NaN
# CurrencyName                 NaN        NaN          NaN         NaN
# CurrencySymbol               NaN        NaN          NaN         NaN
# CountryName                  NaN        NaN          NaN         NaN
# CountryISO                   NaN        NaN          NaN         NaN
# ISIN                         NaN        NaN          NaN         NaN
# CIK                          NaN        NaN          NaN         NaN
# EmployerIdNumber             NaN        NaN          NaN         NaN
# FiscalYearEnd                NaN        NaN          NaN         NaN
# IPODate                      NaN        NaN          NaN         NaN
# InternationalDomestic        NaN        NaN          NaN         NaN
# Sector                       NaN        NaN          NaN         NaN
# Industry                     NaN        NaN          NaN         NaN
# GicSector                    NaN        NaN          NaN         NaN
# GicGroup                     NaN        NaN          NaN         NaN
# GicIndustry                  NaN        NaN          NaN         NaN
# GicSubIndustry               NaN        NaN          NaN         NaN
# Description                  NaN        NaN          NaN         NaN
# Address                      NaN        NaN          NaN         NaN
# AddressData                  NaN        NaN          NaN         NaN
# Listings                     NaN        NaN          NaN         NaN
# Officers                     NaN        NaN          NaN         NaN
# Phone                        NaN        NaN          NaN         NaN
# WebURL                       NaN        NaN          NaN         NaN
# LogoURL                      NaN        NaN          NaN         NaN
# FullTimeEmployees            NaN        NaN          NaN         NaN
#
#                       SplitsDividends  Holders  InsiderTransactions ESGScores  \
# Code                              NaN      NaN                  NaN       NaN
# Type                              NaN      NaN                  NaN       NaN
# Name                              NaN      NaN                  NaN       NaN
# Exchange                          NaN      NaN                  NaN       NaN
# CurrencyCode                      NaN      NaN                  NaN       NaN
# CurrencyName                      NaN      NaN                  NaN       NaN
# CurrencySymbol                    NaN      NaN                  NaN       NaN
# CountryName                       NaN      NaN                  NaN       NaN
# CountryISO                        NaN      NaN                  NaN       NaN
# ISIN                              NaN      NaN                  NaN       NaN
# CIK                               NaN      NaN                  NaN       NaN
# EmployerIdNumber                  NaN      NaN                  NaN       NaN
# FiscalYearEnd                     NaN      NaN                  NaN       NaN
# IPODate                           NaN      NaN                  NaN       NaN
# InternationalDomestic             NaN      NaN                  NaN       NaN
# Sector                            NaN      NaN                  NaN       NaN
# Industry                          NaN      NaN                  NaN       NaN
# GicSector                         NaN      NaN                  NaN       NaN
# GicGroup                          NaN      NaN                  NaN       NaN
# GicIndustry                       NaN      NaN                  NaN       NaN
# GicSubIndustry                    NaN      NaN                  NaN       NaN
# Description                       NaN      NaN                  NaN       NaN
# Address                           NaN      NaN                  NaN       NaN
# AddressData                       NaN      NaN                  NaN       NaN
# Listings                          NaN      NaN                  NaN       NaN
# Officers                          NaN      NaN                  NaN       NaN
# Phone                             NaN      NaN                  NaN       NaN
# WebURL                            NaN      NaN                  NaN       NaN
# LogoURL                           NaN      NaN                  NaN       NaN
# FullTimeEmployees                 NaN      NaN                  NaN       NaN
#
#                       outstandingShares Earnings Financials
# Code                                NaN      NaN        NaN
# Type                                NaN      NaN        NaN
# Name                                NaN      NaN        NaN
# Exchange                            NaN      NaN        NaN
# CurrencyCode                        NaN      NaN        NaN
# CurrencyName                        NaN      NaN        NaN
# CurrencySymbol                      NaN      NaN        NaN
# CountryName                         NaN      NaN        NaN
# CountryISO                          NaN      NaN        NaN
# ISIN                                NaN      NaN        NaN
# CIK                                 NaN      NaN        NaN
# EmployerIdNumber                    NaN      NaN        NaN
# FiscalYearEnd                       NaN      NaN        NaN
# IPODate                             NaN      NaN        NaN
# InternationalDomestic               NaN      NaN        NaN
# Sector                              NaN      NaN        NaN
# Industry                            NaN      NaN        NaN
# GicSector                           NaN      NaN        NaN
# GicGroup                            NaN      NaN        NaN
# GicIndustry                         NaN      NaN        NaN
# GicSubIndustry                      NaN      NaN        NaN
# Description                         NaN      NaN        NaN
# Address                             NaN      NaN        NaN
# AddressData                         NaN      NaN        NaN
# Listings                            NaN      NaN        NaN
# Officers                            NaN      NaN        NaN
# Phone                               NaN      NaN        NaN
# WebURL                              NaN      NaN        NaN
# LogoURL                             NaN      NaN        NaN
# FullTimeEmployees                   NaN      NaN        NaN

# %%
df.head(60)
# Out:
#                                                                       General  \
# Code                                                                      ABX
# Type                                                             Common Stock
# Name                                                 Barrick Gold Corporation
# Exchange                                                                   TO
# CurrencyCode                                                              CAD
# CurrencyName                                                  Canadian Dollar
# CurrencySymbol                                                             C$
# CountryName                                                            Canada
# CountryISO                                                                 CA
# ISIN                                                             CA0679011084
# CIK                                                                      None
# EmployerIdNumber                                                         None
# FiscalYearEnd                                                        December
# IPODate                                                                  None
# InternationalDomestic                                                    None
# Sector                                                        Basic Materials
# Industry                                                                 Gold
# GicSector                                                                None
# GicGroup                                                                 None
# GicIndustry                                                              None
# GicSubIndustry                                                           None
# Description                 Barrick Gold Corporation engages in the explor...
# Address                     TD Canada Trust Tower, Toronto, ON, Canada, M5...
# AddressData                 {'Street': 'TD Canada Trust Tower', 'City': 'T...
# Listings                                                                   {}
# Officers                    {'0': {'Name': 'Mr. John Lawson Thornton', 'Ti...
# Phone                                                            416 861 9911
# WebURL                                                 http://www.barrick.com
# LogoURL                                                 /img/logos/TO/ABX.png
# FullTimeEmployees                                                           0
# UpdatedAt                                                          2021-10-18
# MarketCapitalization                                                      NaN
# MarketCapitalizationMln                                                   NaN
# EBITDA                                                                    NaN
# PERatio                                                                   NaN
# PEGRatio                                                                  NaN
# WallStreetTargetPrice                                                     NaN
# BookValue                                                                 NaN
# DividendShare                                                             NaN
# DividendYield                                                             NaN
# EarningsShare                                                             NaN
# EPSEstimateCurrentYear                                                    NaN
# EPSEstimateNextYear                                                       NaN
# EPSEstimateNextQuarter                                                    NaN
# EPSEstimateCurrentQuarter                                                 NaN
# MostRecentQuarter                                                         NaN
# ProfitMargin                                                              NaN
# OperatingMarginTTM                                                        NaN
# ReturnOnAssetsTTM                                                         NaN
# ReturnOnEquityTTM                                                         NaN
# RevenueTTM                                                                NaN
# RevenuePerShareTTM                                                        NaN
# QuarterlyRevenueGrowthYOY                                                 NaN
# GrossProfitTTM                                                            NaN
# DilutedEpsTTM                                                             NaN
# QuarterlyEarningsGrowthYOY                                                NaN
# TrailingPE                                                                NaN
# ForwardPE                                                                 NaN
# PriceSalesTTM                                                             NaN
# PriceBookMRQ                                                              NaN
#
#                              Highlights  Valuation  SharesStats  Technicals  \
# Code                                NaN        NaN          NaN         NaN
# Type                                NaN        NaN          NaN         NaN
# Name                                NaN        NaN          NaN         NaN
# Exchange                            NaN        NaN          NaN         NaN
# CurrencyCode                        NaN        NaN          NaN         NaN
# CurrencyName                        NaN        NaN          NaN         NaN
# CurrencySymbol                      NaN        NaN          NaN         NaN
# CountryName                         NaN        NaN          NaN         NaN
# CountryISO                          NaN        NaN          NaN         NaN
# ISIN                                NaN        NaN          NaN         NaN
# CIK                                 NaN        NaN          NaN         NaN
# EmployerIdNumber                    NaN        NaN          NaN         NaN
# FiscalYearEnd                       NaN        NaN          NaN         NaN
# IPODate                             NaN        NaN          NaN         NaN
# InternationalDomestic               NaN        NaN          NaN         NaN
# Sector                              NaN        NaN          NaN         NaN
# Industry                            NaN        NaN          NaN         NaN
# GicSector                           NaN        NaN          NaN         NaN
# GicGroup                            NaN        NaN          NaN         NaN
# GicIndustry                         NaN        NaN          NaN         NaN
# GicSubIndustry                      NaN        NaN          NaN         NaN
# Description                         NaN        NaN          NaN         NaN
# Address                             NaN        NaN          NaN         NaN
# AddressData                         NaN        NaN          NaN         NaN
# Listings                            NaN        NaN          NaN         NaN
# Officers                            NaN        NaN          NaN         NaN
# Phone                               NaN        NaN          NaN         NaN
# WebURL                              NaN        NaN          NaN         NaN
# LogoURL                             NaN        NaN          NaN         NaN
# FullTimeEmployees                   NaN        NaN          NaN         NaN
# UpdatedAt                           NaN        NaN          NaN         NaN
# MarketCapitalization        42007855104        NaN          NaN         NaN
# MarketCapitalizationMln      42007.8551        NaN          NaN         NaN
# EBITDA                       7059999744        NaN          NaN         NaN
# PERatio                         13.5378        NaN          NaN         NaN
# PEGRatio                          -2.93        NaN          NaN         NaN
# WallStreetTargetPrice             35.72        NaN          NaN         NaN
# BookValue                        13.314        NaN          NaN         NaN
# DividendShare                      0.36        NaN          NaN         NaN
# DividendYield                    0.0152        NaN          NaN         NaN
# EarningsShare                     1.744        NaN          NaN         NaN
# EPSEstimateCurrentYear              1.5        NaN          NaN         NaN
# EPSEstimateNextYear                1.55        NaN          NaN         NaN
# EPSEstimateNextQuarter                0        NaN          NaN         NaN
# EPSEstimateCurrentQuarter             0        NaN          NaN         NaN
# MostRecentQuarter            2021-06-30        NaN          NaN         NaN
# ProfitMargin                     0.1986        NaN          NaN         NaN
# OperatingMarginTTM               0.4208        NaN          NaN         NaN
# ReturnOnAssetsTTM                0.0727        NaN          NaN         NaN
# ReturnOnEquityTTM                0.1225        NaN          NaN         NaN
# RevenueTTM                  12668000256        NaN          NaN         NaN
# RevenuePerShareTTM                7.123        NaN          NaN         NaN
# QuarterlyRevenueGrowthYOY        -0.053        NaN          NaN         NaN
# GrossProfitTTM               5177000000        NaN          NaN         NaN
# DilutedEpsTTM                     1.744        NaN          NaN         NaN
# QuarterlyEarningsGrowthYOY         0.15        NaN          NaN         NaN
# TrailingPE                          NaN    13.5378          NaN         NaN
# ForwardPE                           NaN    14.8588          NaN         NaN
# PriceSalesTTM                       NaN     3.3161          NaN         NaN
# PriceBookMRQ                        NaN     1.3777          NaN         NaN
#
#                            SplitsDividends  Holders  InsiderTransactions  \
# Code                                   NaN      NaN                  NaN
# Type                                   NaN      NaN                  NaN
# Name                                   NaN      NaN                  NaN
# Exchange                               NaN      NaN                  NaN
# CurrencyCode                           NaN      NaN                  NaN
# CurrencyName                           NaN      NaN                  NaN
# CurrencySymbol                         NaN      NaN                  NaN
# CountryName                            NaN      NaN                  NaN
# CountryISO                             NaN      NaN                  NaN
# ISIN                                   NaN      NaN                  NaN
# CIK                                    NaN      NaN                  NaN
# EmployerIdNumber                       NaN      NaN                  NaN
# FiscalYearEnd                          NaN      NaN                  NaN
# IPODate                                NaN      NaN                  NaN
# InternationalDomestic                  NaN      NaN                  NaN
# Sector                                 NaN      NaN                  NaN
# Industry                               NaN      NaN                  NaN
# GicSector                              NaN      NaN                  NaN
# GicGroup                               NaN      NaN                  NaN
# GicIndustry                            NaN      NaN                  NaN
# GicSubIndustry                         NaN      NaN                  NaN
# Description                            NaN      NaN                  NaN
# Address                                NaN      NaN                  NaN
# AddressData                            NaN      NaN                  NaN
# Listings                               NaN      NaN                  NaN
# Officers                               NaN      NaN                  NaN
# Phone                                  NaN      NaN                  NaN
# WebURL                                 NaN      NaN                  NaN
# LogoURL                                NaN      NaN                  NaN
# FullTimeEmployees                      NaN      NaN                  NaN
# UpdatedAt                              NaN      NaN                  NaN
# MarketCapitalization                   NaN      NaN                  NaN
# MarketCapitalizationMln                NaN      NaN                  NaN
# EBITDA                                 NaN      NaN                  NaN
# PERatio                                NaN      NaN                  NaN
# PEGRatio                               NaN      NaN                  NaN
# WallStreetTargetPrice                  NaN      NaN                  NaN
# BookValue                              NaN      NaN                  NaN
# DividendShare                          NaN      NaN                  NaN
# DividendYield                          NaN      NaN                  NaN
# EarningsShare                          NaN      NaN                  NaN
# EPSEstimateCurrentYear                 NaN      NaN                  NaN
# EPSEstimateNextYear                    NaN      NaN                  NaN
# EPSEstimateNextQuarter                 NaN      NaN                  NaN
# EPSEstimateCurrentQuarter              NaN      NaN                  NaN
# MostRecentQuarter                      NaN      NaN                  NaN
# ProfitMargin                           NaN      NaN                  NaN
# OperatingMarginTTM                     NaN      NaN                  NaN
# ReturnOnAssetsTTM                      NaN      NaN                  NaN
# ReturnOnEquityTTM                      NaN      NaN                  NaN
# RevenueTTM                             NaN      NaN                  NaN
# RevenuePerShareTTM                     NaN      NaN                  NaN
# QuarterlyRevenueGrowthYOY              NaN      NaN                  NaN
# GrossProfitTTM                         NaN      NaN                  NaN
# DilutedEpsTTM                          NaN      NaN                  NaN
# QuarterlyEarningsGrowthYOY             NaN      NaN                  NaN
# TrailingPE                             NaN      NaN                  NaN
# ForwardPE                              NaN      NaN                  NaN
# PriceSalesTTM                          NaN      NaN                  NaN
# PriceBookMRQ                           NaN      NaN                  NaN
#
#                            ESGScores outstandingShares Earnings Financials
# Code                             NaN               NaN      NaN        NaN
# Type                             NaN               NaN      NaN        NaN
# Name                             NaN               NaN      NaN        NaN
# Exchange                         NaN               NaN      NaN        NaN
# CurrencyCode                     NaN               NaN      NaN        NaN
# CurrencyName                     NaN               NaN      NaN        NaN
# CurrencySymbol                   NaN               NaN      NaN        NaN
# CountryName                      NaN               NaN      NaN        NaN
# CountryISO                       NaN               NaN      NaN        NaN
# ISIN                             NaN               NaN      NaN        NaN
# CIK                              NaN               NaN      NaN        NaN
# EmployerIdNumber                 NaN               NaN      NaN        NaN
# FiscalYearEnd                    NaN               NaN      NaN        NaN
# IPODate                          NaN               NaN      NaN        NaN
# InternationalDomestic            NaN               NaN      NaN        NaN
# Sector                           NaN               NaN      NaN        NaN
# Industry                         NaN               NaN      NaN        NaN
# GicSector                        NaN               NaN      NaN        NaN
# GicGroup                         NaN               NaN      NaN        NaN
# GicIndustry                      NaN               NaN      NaN        NaN
# GicSubIndustry                   NaN               NaN      NaN        NaN
# Description                      NaN               NaN      NaN        NaN
# Address                          NaN               NaN      NaN        NaN
# AddressData                      NaN               NaN      NaN        NaN
# Listings                         NaN               NaN      NaN        NaN
# Officers                         NaN               NaN      NaN        NaN
# Phone                            NaN               NaN      NaN        NaN
# WebURL                           NaN               NaN      NaN        NaN
# LogoURL                          NaN               NaN      NaN        NaN
# FullTimeEmployees                NaN               NaN      NaN        NaN
# UpdatedAt                        NaN               NaN      NaN        NaN
# MarketCapitalization             NaN               NaN      NaN        NaN
# MarketCapitalizationMln          NaN               NaN      NaN        NaN
# EBITDA                           NaN               NaN      NaN        NaN
# PERatio                          NaN               NaN      NaN        NaN
# PEGRatio                         NaN               NaN      NaN        NaN
# WallStreetTargetPrice            NaN               NaN      NaN        NaN
# BookValue                        NaN               NaN      NaN        NaN
# DividendShare                    NaN               NaN      NaN        NaN
# DividendYield                    NaN               NaN      NaN        NaN
# EarningsShare                    NaN               NaN      NaN        NaN
# EPSEstimateCurrentYear           NaN               NaN      NaN        NaN
# EPSEstimateNextYear              NaN               NaN      NaN        NaN
# EPSEstimateNextQuarter           NaN               NaN      NaN        NaN
# EPSEstimateCurrentQuarter        NaN               NaN      NaN        NaN
# MostRecentQuarter                NaN               NaN      NaN        NaN
# ProfitMargin                     NaN               NaN      NaN        NaN
# OperatingMarginTTM               NaN               NaN      NaN        NaN
# ReturnOnAssetsTTM                NaN               NaN      NaN        NaN
# ReturnOnEquityTTM                NaN               NaN      NaN        NaN
# RevenueTTM                       NaN               NaN      NaN        NaN
# RevenuePerShareTTM               NaN               NaN      NaN        NaN
# QuarterlyRevenueGrowthYOY        NaN               NaN      NaN        NaN
# GrossProfitTTM                   NaN               NaN      NaN        NaN
# DilutedEpsTTM                    NaN               NaN      NaN        NaN
# QuarterlyEarningsGrowthYOY       NaN               NaN      NaN        NaN
# TrailingPE                       NaN               NaN      NaN        NaN
# ForwardPE                        NaN               NaN      NaN        NaN
# PriceSalesTTM                    NaN               NaN      NaN        NaN
# PriceBookMRQ                     NaN               NaN      NaN        NaN

# %%
df.tail()
# Out:
#                  General Highlights  Valuation  SharesStats  Technicals  \
# Trend                NaN        NaN        NaN          NaN         NaN
# Annual               NaN        NaN        NaN          NaN         NaN
# Balance_Sheet        NaN        NaN        NaN          NaN         NaN
# Cash_Flow            NaN        NaN        NaN          NaN         NaN
# Income_Statement     NaN        NaN        NaN          NaN         NaN
#
#                  SplitsDividends  Holders  InsiderTransactions ESGScores  \
# Trend                        NaN      NaN                  NaN       NaN
# Annual                       NaN      NaN                  NaN       NaN
# Balance_Sheet                NaN      NaN                  NaN       NaN
# Cash_Flow                    NaN      NaN                  NaN       NaN
# Income_Statement             NaN      NaN                  NaN       NaN
#
#                  outstandingShares  \
# Trend                          NaN
# Annual                         NaN
# Balance_Sheet                  NaN
# Cash_Flow                      NaN
# Income_Statement               NaN
#
#                                                            Earnings  \
# Trend             {'2022-12-31': {'date': '2022-12-31', 'period'...
# Annual            {'2021-09-30': {'date': '2021-09-30', 'epsActu...
# Balance_Sheet                                                   NaN
# Cash_Flow                                                       NaN
# Income_Statement                                                NaN
#
#                                                          Financials
# Trend                                                           NaN
# Annual                                                          NaN
# Balance_Sheet     {'currency_symbol': 'USD', 'quarterly': {'2021...
# Cash_Flow         {'currency_symbol': 'USD', 'quarterly': {'2021...
# Income_Statement  {'currency_symbol': 'USD', 'quarterly': {'2021...

# %% [markdown]
# # Bring sample JSON into a dictionary

# %%
# Opening JSON file
f = open(json_file)
 
# returns JSON object as
# a dictionary
json_dict = json.load(f)
#print("json_dict is ",json_dict)
 
# Iterating through the json
# list
print("top level")
for i in json_dict:
    print(i)
print("General")
for i in json_dict['General']:
    print(i)
 
# Closing file
f.close()
# Out:
# top level
# General
# Highlights
# Valuation
# SharesStats
# Technicals
# SplitsDividends
# Holders
# InsiderTransactions
# ESGScores
# outstandingShares
# Earnings
# Financials
# General
# Code
# Type
# Name
# Exchange
# CurrencyCode
# CurrencyName
# CurrencySymbol
# CountryName
# CountryISO
# ISIN
# CIK
# EmployerIdNumber
# FiscalYearEnd
# IPODate
# InternationalDomestic
# Sector
# Industry
# GicSector
# GicGroup
# GicIndustry
# GicSubIndustry
# Description
# Address
# AddressData
# Listings
# Officers
# Phone
# WebURL
# LogoURL
# FullTimeEmployees
# UpdatedAt
